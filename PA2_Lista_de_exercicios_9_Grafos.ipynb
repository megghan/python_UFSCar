# %% [markdown]
# <a href="https://colab.research.google.com/github/megghan/python_UFSCar/blob/main/PA2_Lista_de_exercicios_9_Grafos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='blue'>Lista de exercícios 9 - PA II:</font>  Grafos em Python 3

# %% [markdown]
# ---
#
#
# ## <font color='red'>**Importante**:</font> Mostre o passo-a-passo da solução dos exercícios. Não é **obrigatório** confeccionar nenhum código em Python na solução dos exercícios desta lista.
#
#
# ---

# %% [markdown]
# **Exercício 1**: Execute a linha de código a seguir.

# %%
from numpy import random as rd
from numpy import ceil

W = ceil(100*rd.rand(5,5))
W
# Out:
# array([[55., 56., 97.,  3., 58.],
#        [22., 66., 85., 92., 75.],
#        [46., 15., 71., 36., 27.],
#        [21.,  6., 94., 14., 60.],
#        [85., 13., 16., 58., 76.]])

# %% [markdown]
# (a) Suponha que a matrix `W` gerada na coluna anterior seja a matriz de adjacência de um grafo direcionado e ponderado $G = (V,E,w)$, tal que
# * $V = \{v_0, v_1, v_2, v_3, v_4\}$,
# * $E = V\times V$ e
# * $w(v_i,v_j) :=$ `W[i,j]`.
#
# </br>
#
# Represente graficamente $G$.

# %% [markdown]
# (b) Execute a seção de código abaixo.

# %%
from numpy import where

mask = where(W < 50)
W[mask] = 0
W
# Out:
# array([[55., 56., 97.,  0., 58.],
#        [ 0., 66., 85., 92., 75.],
#        [ 0.,  0., 71.,  0.,  0.],
#        [ 0.,  0., 94.,  0., 60.],
#        [85.,  0.,  0., 58., 76.]])

# %% [markdown]
# Considerando a nova matriz de pesos gerada na célula anterior, represente $G = (V,E,w)$ como sendo uma lista de adjacência.

# %% [markdown]
# **Exercício 2:** Utilizando o algoritmo de Prim, calcule a **árvore geradora mínima** do grafo construído no ítem (a) do exercício anterior.

# %% [markdown]
# **Exercício 3**: Utilizando o algoritmo de Djikstra, calcule o caminho mínimo entre $v_0$ e $v_5$ no grafo $G$ do item (a) do Exercício 1.

# %% [markdown]
# ---
#
# Para os exercícios 4 e 5 detalhados na sequência, considere o grafo não direcionado $G = (V,E)$ representado graficamente na figura a seguir.

# %% [markdown]
# ![grafo_lista.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# **Exercício 6**: Conduza uma varredura BFS sobre o grafo, considerando como raiz o vértice $A$. Ao final, apresente a ordem dos vértices visitados.

# %% [markdown]
# **Exercício 5**: Conduza uma varredura DFS sobre o grafo, considerando como raiz o vértice $A$. Ao final, apresente a ordem dos vértices visitados.

# %% [markdown]
# #<font color='red'>**Atividades Avaliativas Semanais 12 e 13**</font>: Entregar a lista de exercícios resolvida em formato PDF, o que contabilizará como 2 AASs. Cada exercício vale 4 pontos.
